# %% [markdown]
# # Apoorv Task4-To Explore Decision Tree Algorithm.For the given ‘Iris’ dataset

# %%
# Import libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading Dataset

# %%
from sklearn.datasets import load_iris
dat = load_iris()
data = pd.DataFrame(dat.data,columns = dat.feature_names)
y = dat.target

# %%
data.head(n=10)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# 5                5.4               3.9                1.7               0.4
# 6                4.6               3.4                1.4               0.3
# 7                5.0               3.4                1.5               0.2
# 8                4.4               2.9                1.4               0.2
# 9                4.9               3.1                1.5               0.1

# %%
y.shape
# Out:
# (150,)

# %%
data.shape
# Out:
# (150, 4)

# %%
data.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %% [markdown]
# ## Visualisation - Histogram

# %%
# Plot histogram of the given data 
data.hist(figsize = (15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021D5E49AF08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021D5EDAEF88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000021D5EDEBEC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000021D5EE25D88>]],
#       dtype=object)

# %%
sns.pairplot?

# %%
# Pairplot of the given data
sns.pairplot(data)

# %% [markdown]
# ## Implementation of Model

# %%
x = data
y = y
##Spliting the data
from sklearn .model_selection import train_test_split 
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30,random_state = 42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (105, 4)
# (45, 4)
# (105,)
# (45,)

# %% [markdown]
# ## Importing decision Tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import accuracy_score,confusion_matrix

cl= DecisionTreeClassifier()
cl.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ### Accuracy Training data

# %%
predict = cl.predict(x_train)
print("Accuracy of training data : ",accuracy_score(predict,y_train)*100,"%")
print("Confusin matrix of training data :'\n' ",confusion_matrix(predict,y_train))
sns.heatmap(confusion_matrix(predict,y_train),annot = True)
# Out:
# Accuracy of training data :  100.0 %
# Confusin matrix of training data :'
# '  [[31  0  0]
#  [ 0 37  0]
#  [ 0  0 37]]

# %% [markdown]
# ## Accuracy Testing data

# %%
predict = clf.predict(x_test)
print("Accuracy of testing data : ",accuracy_score(predict,y_test)*100,"%")
print("Confusin matrix of testing data :\n ",confusion_matrix(predict,y_test))
sns.heatmap(confusion_matrix(predict,y_test),annot = True)
# Out:
# Accuracy of testing data :  100.0 %
# Confusin matrix of testing data :
#   [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]

# %% [markdown]
# ## It is giving 100% accuracy on the training data and testing data

# %%
plt.figure(figsize  = (20,20))
tree.plot_tree(clf,filled = True,rounded = True,proportion = True,node_ids = True , feature_names = dat.feature_names)
plt.show()

# %%
##Hence divison of the columns can be visualised from this tree
